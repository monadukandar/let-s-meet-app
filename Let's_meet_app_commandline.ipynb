# %%
from json.decoder import JSONDecodeError
import operations
import json
from json import JSONDecodeError

print("Welcome to let's Meet app")
file=open('organizers.json','r+')
try:
    content=json.load(file)
    if 'admin@edyoda.com' not in str(content):
        operations.Register('organizer','members.json','organizers.json','admin','admin@edyoda.com','admin')
    file.close()
except JSONDecodeError:
    operations.Register('organizer','members.json','organizers.json','admin','admin@edyoda.com','admin')
input_1=1
while True:
    print("Press:")
    print("Press 1: Register")
    print("Press 2: Login")
    print(" Press 0: Exit")
    try:
        input_1=int(input())
    except ValueError:
        print("Please enter valid choice ")
        continue
    if input_1==1:
        print("Press :")
        print("Press 1 to Register as Organizer")
        print("Press 2 to Register as Member")
        try:
            key =int(input())
        except ValueError:
            print("Please enter valid choice")
        if key ==1:
            print("Enter Full Name:")
            Name=input()
            print("Enter Email:")
            Email=input()
            print("Enter Password:")
            Password=input()
            if (len(Name)*len(Email)*len(Password))==0 or '@' not in Email or '.com' not in Email:
                print("Please enter valid data")
                continue
            else:
                operations.Register('organizer','members.json','organizers.json',Name,Email,Password)
                print("Registered successfully as Organizer")
        elif key==2:
            print("Enter Full Name:")
            Name=input()
            print("Enter Email:")
            Email=input()
            print("Enter Password:")
            Password=input()
            if (len(Name)*len(Email)*len(Password))==0 or '@' not in Email or '.com' not in Email:
                print("Please enter valid data")
                continue
            else:
                operations.Register('member','members.json','organizers.json',Name,Email,Password)
                print("Registered successfully as Member")
        else:
            print("Please enter valid choice!")
    elif input_1 ==2:
        print("Press: ")
        print("Press 1 to Login as Organizer")
        print("Press 2 to Login as Member")
        try:
            key2=int(input())
        except ValueError:
            print("Please enter valid choice")
        if key2==1:
            print("Enter Email:")
            Email=input()
            print("Enter Password:")
            Password=input()
            func_1=operations.Login('organizer','members.json','organizers.json',Email,Password)
            if func_1==False:
                print("Invalid Credentials")
                continue
            else:
                func_2=open('organizers.json','r')
                func_3=json.load(func_2)
                func_2.close()
                n=""
                for i in range(len(func_3)):
                    if func_3[i]["Email"]==E and func_3[i]["Password"]==P:
                        func_4=func_3[i]["Full Name"]
                        break
                print("Welcome "+str(func_4))
                while True:
                    print("Press :")
                    print("press 1: Create Event")
                    print("press 2: View all Events created")
                    print("press 3: View Event Details by ID")
                    print("press 4: Update Event")
                    print("press 5: Delete Event")
                    print("press 0: Logout")
                    try:
                        option_1=int(input())
                    except ValueError:
                        print("Please enter valid choice")
                    if option_1==1:
                        Event_ID=operations.AutoGenerate_EventID()
                        print("Event ID Generated - "+str(Event_ID))
                        print("Enter Event Name:")
                        Event_Name=input()
                        print("Enter Start Date (YYYY-MM-DD):")
                        Start_dt=input()
                        print("Enter Start Time (HH:MM:SS):")
                        start_time=input()
                        print("Enter End Date (YYYY-MM-DD):")
                        End_dt=input()
                        print("Enter End Time (HH:MM:SS):")
                        End_time=input()
                        print("Enter Total Seats:")
                        try:
                            Cap=int(input())
                        except ValueError:
                            print("Please enter valid data")
                            continue
                        if (len(Event_Name)*len(Event_ID)*len(Start_dt)*len(End_dt)*len(str(Cap)))==0 or len(Start_dt)!=10 or len(End_dt)!=10 or len(start_time)!=8 or len(End_time)!=8 or Start_dt>End_dt or (St_dt==En_dt and St_t>En_t):
                            print("Please enter valid data")
                            continue
                        else:
                            operations.Create_Event(n,'events.json',Event_ID,Event_Name,Start_dt,start_time,End_dt,End_time,[],Cap,Cap)
                            print("Event created successfully")
                    elif option_1==2:
                        event_details=operations.View_Events(n,'events.json')
                        if len(event_details)==0:
                            print("No Events created yet! \n")
                        else:
                            for i in range(len(event_details)):
                                print("Event ID: "+str(event_details[i]['ID']))
                                print("Event Name: " +str(event_details[i]['Name']))
                                print("Organizer: " +str(event_details[i]['Organizer']))
                                print("Start Date: " +str(event_details[i]['Start Date']))
                                print("Start Time: " +str(event_details[i]['Start Time']))
                                print("End Date: " +str(event_details[i]['End Date']))
                                print("End Time: " +str(event_details[i]['End Time']))
                                print("Total Users Registered: "+str(len(event_details[i]["Users Registered"])))
                                print("Seats Available: "+str(event_details[i]['Seats Available']))
                                print('\n')
                    elif option_1==3:
                        print("Enter Event ID")
                        event_id=input()
                        f14=open('events.json','r')
                        try:
                            c14=str(json.load(f14))
                            if event_id not in c14:
                                print("Invalid event ID")
                                continue
                        except JSONDecodeError:
                            print("Events not available")
                            continue
                        d=operations.View_Event_ByID('events.json',event_id)
                        print("Event Name: " +str(d[0]['Name']))
                        print("Organizer: " +str(d[0]['Organizer']))
                        print("Start Date: " +str(d[0]['Start Date']))
                        print("Start Time: " +str(d[0]['Start Time']))
                        print("End Date: " +str(d[0]['End Date']))
                        print("End Time: " +str(d[0]['End Time']))
                        print("Total Seats: "+str(d[0]["Capacity"]))
                        print("Seats Available: "+str(d[0]['Seats Available']))
                        print('\n')
                    elif option_1==4:
                        print("Enter Event ID:")
                        event_id=input()
                        print("Enter detail to be Updated ( Name || Start Date || Start Time || End Time || End Date ): ")
                        details=input()
                        print("Enter new value:")
                        update_details=input()
                        f11=open('events.json','r')
                        try:
                            c11=str(json.load(f11))
                            f11.close()
                        except JSONDecodeError:
                            print("No events created")
                            f11.close()
                            continue
                        if event_id not in c11:
                            print("Invalid event ID")
                            continue
                        if (len(event_id)*len(details)*len(update_details))==0:
                            print("Please enter valid data")
                            continue
                        else:
                            ch=operations.Update_Event(n,'events.json',event_id,details,update_details)
                        if ch==False:
                            print("Cannot update event")
                        else:
                            print("Event updated successfully")
                    elif option_1==5:
                        print("Enter Event ID")
                        event_id=input()
                        f1=open('events.json','r')
                        try:
                            c1=str(json.load(f1))
                            f1.close()
                        except JSONDecodeError:
                            print("No events created")
                            f1.close()
                            continue
                        if event_id not in c1:
                            print("Invalid event ID")
                            continue
                        if len(event_id)==0:
                            print("Please enter valid data")
                            continue
                        else:
                            o1=operations.Delete_Event(n,'events.json',event_id)
                        if o1==True:
                            print("Event deleted successfully")
                        else:
                            print("Cannot delete event")
                    elif option_1==0:
                        break
                    else:
                        print("Ivalid Option")
        elif key2==2:
            print("Enter Email:")
            Email=input()
            print("Enter Password:")
            Password=input()
            funct_1=operations.Login('member','members.json','organizers.json',Email,Password)
            if funct_1==False:
                print("Invalid Credentials")
                continue
            else:
                func_2=open('members.json','r')
                func_3=json.load(func_2)
                func_2.close()
                n=""
                for i in range(len(func_3)):
                    if func_3[i]["Email"]==Email and func_3[i]["Password"]==Password:
                        n=func_3[i]["Full Name"]
                        break
                print("Welcome "+str(n))
                while True:
                    print("Press:")
                    print("1: View Registered Events")
                    print("2: Register for an Event")
                    print("3: Update Password")
                    print("4: View Event Details by ID")
                    print("0: Logout")
                    try:
                        option_2=int(input())
                    except ValueError:
                        print("Please enter valid choice")
                    if option_2==1:
                        all_events=[]
                        upcoming_ongoing=[]
                        operations.fetch_all_events('events.json',n,all_events,upcoming_ongoing)
                        print("All Upcoming/Ongoing Events: ")
                        for i in range(len(upcoming_ongoing)):
                            print("Event Name: " +str(upcoming_ongoing[i]['Name']))
                            print("Start Date: " +str(upcoming_ongoing[i]['Start Date']))
                            print("Start Time: " +str(upcoming_ongoing[i]['Start Time']))
                            print("End Date: " +str(upcoming_ongoing[i]['End Date']))
                            print("End Time: " +str(upcoming_ongoing[i]['End Time']))
                            print("Organizer: " +str(upcoming_ongoing[i]['Organizer']))
                            print('\n')
                    elif option_2==2:
                        l=operations.View_all_events('events.json')
                        if len(l)==0:
                            print("No events available")
                        else:
                            print("All Events: ")
                            for i in range(len(l)):
                                t=l[i]
                                print("Event ID: "+str(t['ID']))
                                print("Event Name: " +str(t['Name']))
                                print("Organizer: "+str(t['Organizer']))
                                print("Start Date: " +str(t['Start Date']))
                                print("Start Time: " +str(t['Start Time']))
                                print("End Date: " +str(t['End Date']))
                                print("End Time: " +str(t['End Time']))
                                print("Seats Available: "+str(t['Seats Available']))
                                print("Total Seats: "+str(t['Capacity']))
                                print('\n')
                        print("Enter Event ID: ")
                        event_ID=input()
                        ch=operations.Register_for_Event('events.json',event_ID,n)
                        f44=open('events.json','r')
                        c44=str(json.load(f44))
                        if event_ID not in c44:
                            print("Invalid Event ID")
                        if ch==True:
                            print("Successfully Registered")
                        else:
                            print("Event seats are full! \n")
                    elif option_2==3:
                        print("Enter new password")
                        password=input()
                        if(len(password))<4:
                            print("Please enter valid data")
                            continue
                        operation_1=operations.Update_Password('members.json',n,password)
                        if operation_1==True:
                            print("Password updated successfully")
                        else:
                            print("Cannot update password")
                    elif option_2==4:
                        print("Enter Event ID")
                        event_id=input()
                        f14=open('events.json','r')
                        try:
                            c14=str(json.load(f14))
                            if event_id not in c14:
                                print("Invalid event ID")
                                continue
                        except JSONDecodeError:
                            print("Events not available")
                            continue
                        d=operations.View_Event_ByID('events.json',event_id)
                        print("Event Name: " +str(d[0]['Name']))
                        print("Start Date: " +str(d[0]['Start Date']))
                        print("Start Time: " +str(d[0]['Start Time']))
                        print("End Date: " +str(d[0]['End Date']))
                        print("End Time: " +str(d[0]['End Time']))
                        print("End Time: " +str(d[0]['End Time']))
                        print("Organizer: "+str(d[0]["Organizer"]))
                        print("Seats Available: "+str(d[0]['Seats Available']))
                        print('\n')
                    elif option_2==0:
                        break
                    else:
                        print("Please enter valid option")
                        continue
    elif input_1==0:
        break
    else:
        print("Please enter valid option")
        continue
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 from json.decoder import JSONDecodeError
# ----> 2 import operations
#       3 import json
#       4 from json import JSONDecodeError
#
# ModuleNotFoundError: No module named 'operations'
